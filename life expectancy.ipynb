# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('Life Expectancy Data.csv')

# %%
dataset.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
dataset.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
# renaming the columns
dataset.columns = ['country', 'year', 'status', 'life_expectancy', 'adult_mortality', 'infant_deaths', 'alcohol',
                   'percentage_expenditure', 'hepatitis_B', 'measles', 'bmi', 'under_5_deaths', 'polio', 'total_expenditure',
                   'diphtheria', 'hiv_aids', 'gdp', 'population', 'thin_1-19_years','thin_5-9_years',
                   'income_comp_of_resources', 'schooling']

# %%
# checking the number of unique items in the dataset
dataset.apply(lambda x: len(x.unique()))
# Out:
# country                      193
# year                          16
# status                         2
# life_expectancy              363
# adult_mortality              426
# infant_deaths                209
# alcohol                     1077
# percentage_expenditure      2328
# hepatitis_B                   88
# measles                      958
# bmi                          609
# under_5_deaths               252
# polio                         74
# total_expenditure            819
# diphtheria                    82
# hiv_aids                     200
# gdp                         2491
# population                  2279
# thin_1-19_years              201
# thin_5-9_years               208
# income_comp_of_resources     626
# schooling                    174
# dtype: int64

# %%
# checking for duplicate rows
dataset.duplicated().sum()
# Out:
# 0

# %%
# checking for outliers
datasetn = dataset.drop(columns=["year","country","status"])
def outlier_count(col, data = datasetn):
    
    print("\n"+15*'-' + col + 15*'-'+"\n")
    
    q75, q25 = np.percentile(data[col], [75, 25])
    iqr = q75 - q25
    min_val = q25 - (iqr*1.5)
    max_val = q75 + (iqr*1.5)
    outlier_count = len(np.where((data[col] > max_val) | (data[col] < min_val))[0])
    outlier_percent = round(outlier_count/len(data[col])*100, 2)
    print('Number of outliers: {}'.format(outlier_count))
    print('Percent of data that is outlier: {}%'.format(outlier_percent))

for col in datasetn:
    outlier_count(col)
# Out:
# ---------------life_expectancy---------------
#
# Number of outliers: 0
# Percent of data that is outlier: 0.0%
#
# ---------------adult_mortality---------------
#
# Number of outliers: 0
# Percent of data that is outlier: 0.0%
#
# ---------------infant_deaths---------------
#
# Number of outliers: 315
# Percent of data that is outlier: 10.72%
#
# ---------------alcohol---------------
#
# Number of outliers: 0
# Percent of data that is outlier: 0.0%
#
# ---------------percentage_expenditure---------------
#
# Number of outliers: 389
# Percent of data that is outlier: 13.24%
#
# ---------------hepatitis_B---------------
#
# Number of outliers: 0
# Percent of data that is outlier: 0.0%
#
# ---------------measles---------------
#
# Number of outliers: 542
# Percent of data that is outlier: 18.45%
#
# ---------------bmi---------------
#
# Number of outliers: 0
# Percent of data that is outlier: 0.0%
#
# ---------------under_5_deaths---------------
#
# Number of outliers: 394
# ...

# %%
# checking for empty rows in the dataset
dataset.isnull().sum()
# Out:
# country                       0
# year                          0
# status                        0
# life_expectancy              10
# adult_mortality              10
# infant_deaths                 0
# alcohol                     194
# percentage_expenditure        0
# hepatitis_B                 553
# measles                       0
# bmi                          34
# under_5_deaths                0
# polio                        19
# total_expenditure           226
# diphtheria                   19
# hiv_aids                      0
# gdp                         448
# population                  652
# thin_1-19_years              34
# thin_5-9_years               34
# income_comp_of_resources    167
# schooling                   163
# dtype: int64

# %%
# filling missing values 
dataset['adult_mortality'].fillna(dataset['adult_mortality'].mode()[0], inplace = True)
dataset['life_expectancy'].fillna(dataset['life_expectancy'].mode()[0], inplace = True)
dataset['alcohol'].fillna(dataset['alcohol'].mode()[0], inplace = True)
dataset['hepatitis_B'].fillna(dataset['hepatitis_B'].mode()[0], inplace = True)
dataset['bmi'].fillna(dataset['bmi'].mode()[0], inplace = True)
dataset['polio'].fillna(dataset['polio'].mode()[0], inplace = True)
dataset['total_expenditure'].fillna(dataset['total_expenditure'].mode()[0], inplace = True)
dataset['diphtheria'].fillna(dataset['diphtheria'].mode()[0], inplace = True)
dataset['gdp'].fillna(dataset['gdp'].mode()[0], inplace = True)
dataset['population'].fillna(dataset['population'].mode()[0], inplace = True)
dataset['thin_1-19_years'].fillna(dataset['thin_1-19_years'].mode()[0], inplace = True)
dataset['thin_5-9_years'].fillna(dataset['thin_5-9_years'].mode()[0], inplace = True)
dataset['income_comp_of_resources'].fillna(dataset['income_comp_of_resources'].mode()[0], inplace = True)
dataset['schooling'].fillna(dataset['schooling'].mode()[0], inplace = True)

# %%
# rechecking for empty rows in the dataset
dataset.isnull().sum()
# Out:
# country                     0
# year                        0
# status                      0
# life_expectancy             0
# adult_mortality             0
# infant_deaths               0
# alcohol                     0
# percentage_expenditure      0
# hepatitis_B                 0
# measles                     0
# bmi                         0
# under_5_deaths              0
# polio                       0
# total_expenditure           0
# diphtheria                  0
# hiv_aids                    0
# gdp                         0
# population                  0
# thin_1-19_years             0
# thin_5-9_years              0
# income_comp_of_resources    0
# schooling                   0
# dtype: int64

# %%
# count of status column

ax = sns.countplot(x = 'status', data = dataset);
plt.title('count of developed and developing countries', fontsize = 15)
for i in ax.patches:
    ax.text(i.get_x()+.01,i.get_height()+20,str(int((i.get_height()))),
            rotation=0,fontsize=10,color='black');

# %%
# correlation matrix
plt.figure(figsize = (20,10))
sns.heatmap(dataset.corr(),annot=True, cmap="coolwarm");

# %%
# distribution plots
for i in dataset.columns:
    sns.displot(dataset[i], kde= True);

# %%
# scatter plot
for i in dataset.columns:
    dataset.plot(kind = 'scatter', x = i, y = 'life_expectancy');

# %%
datasetn = dataset.drop(columns=["year","country","status"])

# %%
def outlier_count(col, data = datasetn):
    
    print("\n"+15*'-' + col + 15*'-'+"\n")
    
    q75, q25 = np.percentile(data[col], [75, 25])
    iqr = q75 - q25
    min_val = q25 - (iqr*1.5)
    max_val = q75 + (iqr*1.5)
    outlier_count = len(np.where((data[col] > max_val) | (data[col] < min_val))[0])
    outlier_percent = round(outlier_count/len(data[col])*100, 2)
    print('Number of outliers: {}'.format(outlier_count))
    print('Percent of data that is outlier: {}%'.format(outlier_percent))

# %%
for col in datasetn:
    outlier_count(col)
# Out:
# ---------------life_expectancy---------------
#
# Number of outliers: 17
# Percent of data that is outlier: 0.58%
#
# ---------------adult_mortality---------------
#
# Number of outliers: 85
# Percent of data that is outlier: 2.89%
#
# ---------------infant_deaths---------------
#
# Number of outliers: 315
# Percent of data that is outlier: 10.72%
#
# ---------------alcohol---------------
#
# Number of outliers: 1
# Percent of data that is outlier: 0.03%
#
# ---------------percentage_expenditure---------------
#
# Number of outliers: 389
# Percent of data that is outlier: 13.24%
#
# ---------------hepatitis_B---------------
#
# Number of outliers: 305
# Percent of data that is outlier: 10.38%
#
# ---------------measles---------------
#
# Number of outliers: 542
# Percent of data that is outlier: 18.45%
#
# ---------------bmi---------------
#
# Number of outliers: 0
# Percent of data that is outlier: 0.0%
#
# ---------------under_5_deaths---------------
#
# Number of outliers: 394
# ...

# %%
# converting categorical columns to numeric
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
dataset['status']=le.fit_transform(dataset['status'])
dataset['country']= le.fit_transform(dataset['country'])

# %%
dataset
# Out:
#       country  year  status  life_expectancy  adult_mortality  infant_deaths  \
# 0           0  2015       1             65.0            263.0             62
# 1           0  2014       1             59.9            271.0             64
# 2           0  2013       1             59.9            268.0             66
# 3           0  2012       1             59.5            272.0             69
# 4           0  2011       1             59.2            275.0             71
# ...       ...   ...     ...              ...              ...            ...
# 2933      192  2004       1             44.3            723.0             27
# 2934      192  2003       1             44.5            715.0             26
# 2935      192  2002       1             44.8             73.0             25
# 2936      192  2001       1             45.3            686.0             25
# 2937      192  2000       1             46.0            665.0             24
#
# ...

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
scaler.fit(dataset.drop('life_expectancy', axis=1))
scaled_features = scaler.transform(dataset.drop('life_expectancy', axis=1))

# %%
x = dataset[['country', 'year', 'status', 'adult_mortality', 'infant_deaths', 'alcohol', 'percentage_expenditure',
             'hepatitis_B', 'measles', 'bmi', 'under_5_deaths', 'polio', 'total_expenditure', 'diphtheria',
             'hiv_aids', 'gdp', 'population', 'thin_1-19_years', 'thin_5-9_years', 'income_comp_of_resources', 'schooling']] # independent variables/features are classified as x
y = dataset['life_expectancy'] # Target variable that we are trying to predict are classified as y

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(scaled_features, y, test_size = 0.3, random_state = 101)

# %% [markdown]
# #### LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# 71.4357787618066

# %%
coeff_df = pd.DataFrame(lr.coef_, x.columns, columns=['Coefficient'])
# create a dataframe showing the features and their corresponding coefficient
# lrm.coef is the data x.columns is the index

coeff_df
# Out:
#                           Coefficient
# country                      0.447989
# year                         0.000250
# status                      -1.425678
# adult_mortality             -2.949415
# infant_deaths                2.423236
# alcohol                      0.475228
# percentage_expenditure      -0.017849
# hepatitis_B                 -0.335034
# measles                     -0.004912
# bmi                          1.563955
# under_5_deaths              -2.319023
# polio                        0.632139
# total_expenditure            0.241791
# diphtheria                   0.708415
# hiv_aids                    -0.324600
# gdp                          0.267357
# population                  -0.001067
# thin_1-19_years             -0.588548
# thin_5-9_years               0.098567
# income_comp_of_resources     1.161854
# schooling                    2.957288

# %%
pred = lr.predict(x_test)
plt.scatter(y_test,pred) #shows the correlation between pred and y_test

# %%
sns.distplot((y_test - pred), bins=50); #shows d difference btwn actual values y_test and pred

# %%
from sklearn import metrics
print('MAE: ', metrics.mean_absolute_error(y_test, pred))
print('MSE: ', metrics.mean_squared_error(y_test, pred))
print('RMSE: ', np.sqrt(metrics.mean_absolute_error(y_test, pred)))

print('explained variance score: ', metrics.explained_variance_score(y_test,pred)) # shows d rlatnship btwn actual values and pred

# the higher the explained_variance_score the more accurate the model.
# Out:
# MAE:  2.9718046772485467
# MSE:  15.386271332301499
# RMSE:  1.7238923044229146
# explained variance score:  0.8222655820995265

# %%
dataset.columns
# Out:
# Index(['country', 'year', 'status', 'life_expectancy', 'adult_mortality',
#        'infant_deaths', 'alcohol', 'percentage_expenditure', 'hepatitis_B',
#        'measles', 'bmi', 'under_5_deaths', 'polio', 'total_expenditure',
#        'diphtheria', 'hiv_aids', 'gdp', 'population', 'thin_1-19_years',
#        'thin_5-9_years', 'income_comp_of_resources', 'schooling'],
#       dtype='object')

# %%
print('test score: ', lr.score(x_test, y_test))
print('train score: ', lr.score(x_train, y_train))
# Out:
# test score:  0.8222653693892368
# train score:  0.8192745403342538

# %% [markdown]
# #### RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rfr_pred = rfr.predict(x_test)

# %%
from sklearn import metrics
print('MAE: ', metrics.mean_absolute_error(y_test, rfr_pred))
print('MSE: ', metrics.mean_squared_error(y_test, rfr_pred))
print('RMSE: ', np.sqrt(metrics.mean_absolute_error(y_test, rfr_pred)))

print('explained variance score: ', metrics.explained_variance_score(y_test,rfr_pred)) # shows d rlatnship btwn actual values and pred

# the higher the explained_variance_score the more accurate the model.
# Out:
# MAE:  1.088632653061224
# MSE:  3.0460237097505605
# RMSE:  1.0433756049770495
# explained variance score:  0.9648229740776731

# %%
print('test score: ', rfr.score(x_test, y_test))
print('train score: ', rfr.score(x_train, y_train))
# Out:
# test score:  0.9648138338918035
# train score:  0.9941676386751032

# %% [markdown]
# #### SUPPORT VECTOR REGRESSOR

# %%
from sklearn.svm import SVR
svr = SVR(kernel='linear')
svr.fit(x_train, y_train)
# Out:
# SVR(kernel='linear')

# %%
svr_pred = svr.predict(x_test)

# %%
from sklearn import metrics
print('MAE: ', metrics.mean_absolute_error(y_test, svr_pred))
print('MSE: ', metrics.mean_squared_error(y_test, svr_pred))
print('RMSE: ', np.sqrt(metrics.mean_absolute_error(y_test, svr_pred)))

print('explained variance score: ', metrics.explained_variance_score(y_test, svr_pred)) # shows d rlatnship btwn actual values and pred

# the higher the explained_variance_score the more accurate the model.
# Out:
# MAE:  2.932005930443448
# MSE:  15.777018509652015
# RMSE:  1.712310115149545
# explained variance score:  0.8177601997964117

# %%
print('test score: ', svr.score(x_test, y_test))
print('train score: ', svr.score(x_train, y_train))
# Out:
# test score:  0.8177516503907428
# train score:  0.8106298283561594
